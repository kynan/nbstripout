# %% [markdown]
# # Test Notebook for nbstripout error types

# %%
import sys
print('This is not an error')
sys.stderr.write('This is stderr\n')
import notalibrary
# Out:
# This is not an error
# This is stderr
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 4
#       2 print('This is not an error')
#       3 sys.stderr.write('This is stderr\n')
# ----> 4 import notalibrary
#
# ModuleNotFoundError: No module named 'notalibrary'

# %%
'a'
# Out:
# 'a'

# %%
print('test')
# Out:
# test
