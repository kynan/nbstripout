# %%
"This is the new Jupyter notebook"
# Out:
# 'This is the new Jupyter notebook'

# %%
ls
# Out:
# 00_notebook_tour.ipynb          formatting.ipynb  sympy_quantum_computing.ipynb01_notebook_introduction.ipynb  python-logo.svg   trapezoid_rule.ipynbdisplay_protocol.ipynb          sympy.ipynb

# %%
def f(x):    """My function    x : parameter"""        return x+1print "f(3) = ", f(3)
# Out:
# f(3) =  4
